# %% [markdown]
# # SCH23390 TFC Analysis
#
# ### Table of Contents
#
# 1. [Experiment Info](#ei)
# 2. [Imports and Set Up](#is)
# 3. [Training](#tr)
#     1. [Load and Clean Training Data](#lctr)
#     2. [Plot Training Data](#pltr)
# 4. [Tone Test](#to)
#     1. [Load and Clean Tone Test Data](#lcto)
#     2. [Plot Tone Test Data](#plto)
# 5. [Context Test](#co)
#     1. [Load and Clean Tone Test Data](#lcco)

# %% [markdown]
# <a id='ei'></a>
#
# ## Experiment Info:
# - Inject Saline or SCH23390 (.05 or 0.1 mg/kg) 30 mins before training in TFC
# - Train in trace fear conditioning (TFC)
#     - 240s baseline
#     - 20s, 3kHz, 85db tone
#     - 20s trace interval
#     - 3 x 0.3mA, 2s shocks
#     - 240s ITI
# - Tone test
#     - 180s baseline
#     - same tone
#     - 6 trials
# - 10m context test

# %% [markdown]
# <a id='is'></a>
# ## Imports and Script-Wide Set Up

# %%
import sys
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# insert path to fearData.py below
sys.path.insert(0, '/Users/jake/python_scripts/wiltgenlab/fearData/')
import fearData as fd
# %matplotlib inline

# %%
# set path to correct experiment
path = '/Users/jake/Box/WiltgenLab expts/JW LC/2021-11 SCH23390 TFC Attempt 2/'
grp_label_file = '/Users/jake/Box/WiltgenLab expts/JW LC/JW LC Expt Tracker.xlsx'
expt_name = 'SCH23390 TFC Attempt 2'

# %%
# set script-wide plotting settings
fd.presentation_style()
sns.set_palette('Paired')

# %% [markdown]
# <a id='tr'></a>
# ## Training

# %% [markdown]
# <a id='lctr'></a>
# ### Load and Clean Training Data

# %%
# load data
train_file = f'{path}data-raw/2021-11-10 SCH23390 TFC Train.csv'
df_train_raw = fd.load_df(train_file)

# clean data (take from MedAssociates format to simple csv table)
df_train = fd.clean_df(df_train_raw)

# add group labels to animals
df_train = fd.add_group_labels(df_train, grp_file=grp_label_file, exp_name=expt_name, grp2='Condition')


# create a df w/ values averaged for each phase (i.e. baseline, tone, etc.) w/in each animal
df_train_total = fd.total_df(df_train, grp2='Condition')

# %% [markdown]
# <a id='pltr'></a>
# ### Plot Training Data

# %%
# binned plot (w/ time as x)

fd.tfc_plot(df_train, has_hue=True, hue='Condition', fig_name='Training')
plt.legend(fontsize = 50);

# Save figure
#plt.savefig(f'{path}/figures/{expt_name} train bins.png')
min_bins = [i for i in range(len(df_train['Component Name'].unique())) if (i+1) % 3 == 0]
min_labs = [ i+1 for i in range(len(min_bins)) ]
plt.xticks(min_bins, min_labs, rotation=0)
plt.xlabel('Time (min)', size = 36);
plt.savefig(f'{path}figs/SCH23390 TFC Train bins.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-a690e6ffecb6> in <module>()
#      10 plt.xticks(min_bins, min_labs, rotation=0)
#      11 plt.xlabel('Time (min)', size = 36);
# ---> 12 plt.savefig(f'{path}figs/SCH23390 TFC Train bins.png')
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
# --> 512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#     513
#     514     def print_to_buffer(self):
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# /anaconda3/lib/python3.6/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2167                 fp = builtins.open(filename, "r+b")
#    2168             else:
# -> 2169                 fp = builtins.open(filename, "w+b")
#    2170
#    2171         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jake/Box/WiltgenLab expts/JW LC/2021-11 SCH23390 TFC Attempt 2/figs/SCH23390 TFC Train bins.png'

# %%
# bar plot grouped by phase

fd.tfc_barplot(df_train_total, hue='Condition', order=['baseline', 'tone', 'trace'], fig_name='Training', pts=True)
plt.ylim(0, 100)

# Save figure
#plt.savefig(f'{path}/figs/SCH23390 TFC Train total.png')
# Out:
# (0.0, 100.0)

# %%
fd.tfc_plot(df_train_total, xvar = 'Phase', min_bins= False,tone_squares=False, trace_squares=False,
         shock_line=False,hue='Condition', order = ['baseline', 'tone', 'trace'], 
         errwidth=10,scale = 2, marker_size = 4500)
plt.ylim((0,100));
plt.xlabel('')
plt.ylabel('')
ax = plt.gca()
ax.legend(markerscale = .5, fontsize = 70)
ax.set_xticklabels(['Baseline', 'Tone', 'Trace'], size = 70)

#plt.savefig(f'{path}/figures/LC ArchT TFC Train Total Line.png')
# Out:
# [Text(0, 0, 'Baseline'), Text(1, 0, 'Tone'), Text(2, 0, 'Trace')]

# %% [markdown]
# <a id='to'></a>
# ## Tone Test

# %% [markdown]
# <a id='lcto'></a>
# ### Load and Clean Tone Test Data

# %%
# load data
tone_file = f'{path}data-raw/2021-11-11 SCH23390 TFC Test.csv'
df_tone_raw = fd.load_df(tone_file)

# clean data (take from MedAssociates format to simple csv table)
df_tone = fd.clean_df(df_tone_raw)

# add group labels to animals
df_tone = fd.add_group_labels(df_tone, grp_file=grp_label_file, exp_name=expt_name, grp2= 'Condition')

# exclude animal that didn't get some shocks
#df_tone = df_tone[df_tone.Animal != '306']


# create a df w/ values averaged for each phase (i.e. baseline, tone, etc.) w/in each animal
df_tone_total = fd.total_df(df_tone, grp2='Condition')

# %% [markdown]
# <a id='plto'></a>
# ### Plot Tone Test Data

# %%
# binned plot

fd.tfc_plot(df_tone, has_hue=True, hue='Condition', fig_name='Tone Test')
plt.legend(fontsize=50);


# Save figure
#plt.savefig(f'{path}/figures/{expt_name} tone test trial.png')

# %%
# bar plot

fd.tfc_barplot(df_tone_total, hue='Condition', order=['baseline', 'tone', 'trace'], 
               fig_name='Tone Test', pts = True)
plt.ylim((0,85))

#L.get_texts()[0].set_text('ArchT')
#L.get_texts()[1].set_text('No ArchT')

# Save figure
#plt.savefig(f'{path}/figures/{expt_name} tone test total bar.png')
# Out:
# (0.0, 85.0)

# %%
#prism_df = df_tone_total.groupby(['Phase', 'Condition', 'Animal']).mean()

# %%
#prism_df.to_csv(f'{path}tone_test.csv')

# %%
fd.tfc_plot(df_tone_total, xvar = 'Phase', min_bins= False,tone_squares=False, trace_squares=False,
         shock_line=False,hue='Condition', order = ['baseline', 'tone', 'trace', ], 
         errwidth=10,scale = 2, marker_size = 4500)

plt.ylim((0,80));
plt.xlabel('');
plt.ylabel('');
ax = plt.gca()
ax.set_xticklabels(['Baseline', 'Tone', 'Trace'], size = 70);

L=ax.legend(markerscale = .5, fontsize = 70)



#plt.savefig(f'{path}/figures/{expt_name} tone test total line.png')

# %% [markdown]
# <a id ='co' ></a>
# ## Context Test

# %% [markdown]
# <a id='lcco'></a>
# ### Load and Clean Context Test Data

# %%
# load data
ctx_file = f'{path}data-raw/2021-11-12 SCH23390 TFC Ctx Test.csv'

df_ctx_raw = fd.load_df(ctx_file)

# clean data (take from MedAssociates format to simple csv table)
df_ctx = fd.clean_df(df_ctx_raw, ctx=True)

# add group labels to animals
df_ctx = fd.add_group_labels(df_ctx, grp_file=grp_label_file, exp_name=expt_name, grp2='Condition')

# exclusions


# create total df
df_ctx_total = fd.total_df(df_ctx, grp2='Condition')

# %%
fd.tfc_plot(df_ctx, has_hue=True, squares=False, ylim=(0,100), hue='Condition', 
            fig_name='Context Test', tone_squares = False, shock_line= False)
plt.legend(fontsize=50);

# %%
fd.tfc_barplot(df_ctx_total, ctx=True, pts = True, hue='Condition', ylim=(0,80), fig_name=('Context Test'))
plt.ylim(0,60)

plt.ylabel('Freezing (%)')
#plt.savefig(f'{path}/figures/{expt_name} ctx test bar.png')
# Out:
# /Users/jake/python_scripts/wiltgenlab/fearData/fearData.py:372: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([], [])
# Text(0, 0.5, 'Freezing (%)')
